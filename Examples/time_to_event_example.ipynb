# %%
from bizkit.time_to_event import time_to_event

# %%
model = time_to_event()

# %%
from lifelines.datasets import load_dd

data = load_dd()
data.head()
# Out:
#       ctryname  cowcode2  politycode  ... start_year duration observed
# 0  Afghanistan       700       700.0  ...       1946        7        1
# 1  Afghanistan       700       700.0  ...       1953       10        1
# 2  Afghanistan       700       700.0  ...       1963       10        1
# 3  Afghanistan       700       700.0  ...       1973        5        0
# 4  Afghanistan       700       700.0  ...       1978        1        0
#
# [5 rows x 12 columns]

# %%
T = data["duration"]
E = data["observed"]

# %%
model.fit_plot(dataframe=data,durations='duration')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7883">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8ea72100-8af4-4595-bb9f-bf4415182668" data-root-id="7885"></div>

# %%
model.fit_plot(dataframe=data,durations='duration',group='regime')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8266">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ade83c5c-a0a9-4252-bbb9-94adfc1ba36f" data-root-id="8268"></div>

# %%
model.significance_results(data,durations='duration',group='regime')
# Out:
# <style  type="text/css" >
#     #T_07e71a30_b2dd_11e9_92dd_0242ac1c0002row0_col0 {
#             color:  red;
#         }    #T_07e71a30_b2dd_11e9_92dd_0242ac1c0002row1_col0 {
#             color:  green;
#         }    #T_07e71a30_b2dd_11e9_92dd_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_07e71a30_b2dd_11e9_92dd_0242ac1c0002row3_col0 {
#             color:  green;
#         }    #T_07e71a30_b2dd_11e9_92dd_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_07e71a30_b2dd_11e9_92dd_0242ac1c0002row5_col0 {
#             color:  green;
#         }    #T_07e71a30_b2dd_11e9_92dd_0242ac1c0002row6_col0 {
#             color:  green;
#         }    #T_07e71a30_b2dd_11e9_92dd_0242ac1c0002row7_col0 {
#             color:  green;
#         }    #T_07e71a30_b2dd_11e9_92dd_0242ac1c0002row8_col0 {
#             color:  green;
#         }    #T_07e71a30_b2dd_11e9_92dd_0242ac1c0002row9_col0 {
#             color:  green;
# ...
